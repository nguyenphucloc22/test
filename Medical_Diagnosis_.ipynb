# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenphucloc22/test/blob/main/Medical_Diagnosis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=470914bcca30b3bd6d1d478269bcb3445330db67c1e78717179f019324baa541
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy.control as ctrl
Fever = np.linspace(0.1, 1, num=100)
Headache = np.linspace(0.1, 1, num=100)
Nausea = np.linspace(0.1, 1, num=100)
Vomiting = np.linspace(0.1, 1, num=100)
Jaundice = np.linspace(0.1, 1, num=100)
Enlarge_Liver = np.linspace(0.1, 1, num=100)
Joint_Pain = np.linspace(0.1, 1, num=100)
Body_Weakness = np.linspace(0.1, 1, num=100)
Dizziness = np.linspace(0.1, 1, num=100)
Loss_of_Appetite = np.linspace(0.1, 1, num=100)
MP = np.linspace(0.1, 1.0, num=100)
Diagnosis_Result = np.linspace(0.1, 1, num=100)
Fever = ctrl.Antecedent(Fever, 'Fever')
Headache = ctrl.Antecedent(Headache, 'Headache')
Nausea = ctrl.Antecedent(Nausea, 'Nausea')
Vomiting = ctrl.Antecedent(Vomiting, 'Vomiting')
Jaundice = ctrl.Antecedent(Jaundice, 'Jaundice')
Enlarge_Liver = ctrl.Antecedent(Enlarge_Liver, 'Enlarge_Liver')
Joint_Pain = ctrl.Antecedent(Joint_Pain, 'Joint_Pain')
Body_Weakness = ctrl.Antecedent(Body_Weakness, 'Body_Weakness')
Dizziness = ctrl.Antecedent(Dizziness, 'Dizziness')
Loss_of_Appetite = ctrl.Antecedent(Loss_of_Appetite, 'Loss_of_Appetite')
MP = ctrl.Antecedent(MP, 'MP')
Diagnosis_Result = ctrl.Consequent(Diagnosis_Result, 'Diagnosis_Result')
names_Fever = ['Mild','Moderate', 'Severe','Very Severe']
names_Headache = ['Mild','Moderate', 'Severe','Very Severe']
names_Nausea = ['Mild','Moderate', 'Severe','Very Severe']
names_Vomiting= ['Mild','Moderate', 'Severe','Very Severe']
names_Jaundice = ['Mild','Moderate', 'Severe','Very Severe']
names_Enlarge_Liver = ['Mild','Moderate', 'Severe','Very Severe']
names_Joint_Pain = ['Mild','Moderate', 'Severe','Very Severe']
names_Body_Weakness = ['Mild','Moderate', 'Severe','Very Severe']
names_Dizziness= ['Mild','Moderate', 'Severe','Very Severe']
names_Loss_of_Appetite= ['Mild','Moderate', 'Severe','Very Severe']
names_MP= ['Mild','Moderate', 'Severe','Very Severe']
names_Diagnosis_Result= ['Mild','Moderate', 'Severe','Very Severe']
Fever.automf(names=names_Fever)
Headache.automf(names=names_Headache)
Nausea.automf(names=names_Nausea)
Vomiting.automf(names=names_Vomiting)
Jaundice.automf(names=names_Jaundice)
Enlarge_Liver.automf(names=names_Enlarge_Liver)
Joint_Pain.automf(names=names_Joint_Pain)
Body_Weakness.automf(names=names_Body_Weakness)
Dizziness.automf(names=names_Dizziness)
Loss_of_Appetite.automf(names=names_Loss_of_Appetite)
MP.automf(names=names_MP)
Diagnosis_Result.automf(names=names_Diagnosis_Result)
rule1 = ctrl.Rule(Fever['Mild'] & Headache['Mild'] & Nausea['Mild'] & Vomiting['Mild'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Mild'] & Body_Weakness['Mild'] & Dizziness['Severe'] & Loss_of_Appetite['Mild'] & MP['Mild'], Diagnosis_Result['Mild'])
rule2 = ctrl.Rule(Fever['Moderate'] & Headache['Mild'] & Nausea['Mild'] & Vomiting['Mild'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Moderate'] & Body_Weakness['Moderate'] & Dizziness['Severe'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule3 = ctrl.Rule(Fever['Severe'] & Headache['Moderate'] & Nausea['Mild'] & Vomiting['Mild'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Mild'] & Body_Weakness['Severe'] & Dizziness['Severe'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Severe'])
rule4 = ctrl.Rule(Fever['Very Severe'] & Headache['Mild'] & Nausea['Mild'] & Vomiting['Mild'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Severe'] & Body_Weakness['Severe'] & Dizziness['Mild'] & Loss_of_Appetite['Mild'] & MP['Severe'], Diagnosis_Result['Very Severe'])
rule5 = ctrl.Rule(Fever['Moderate'] & Headache['Mild'] & Nausea['Mild'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Moderate'] & Body_Weakness['Moderate'] & Dizziness['Moderate'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule6 = ctrl.Rule(Fever['Mild'] & Headache['Moderate'] & Nausea['Moderate'] & Vomiting['Mild'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Mild'] & Body_Weakness['Mild'] & Dizziness['Moderate'] & Loss_of_Appetite['Mild'] & MP['Mild'], Diagnosis_Result['Mild'])
rule7 = ctrl.Rule(Fever['Mild'] & Headache['Mild'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Severe'] & Body_Weakness['Severe'] & Dizziness['Moderate'] & Loss_of_Appetite['Moderate'] & MP['Moderate'], Diagnosis_Result['Severe'])
rule8 = ctrl.Rule(Fever['Moderate'] & Headache['Moderate'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Moderate'] & Enlarge_Liver['Moderate'] & Joint_Pain['Moderate'] & Body_Weakness['Moderate'] & Dizziness['Moderate'] & Loss_of_Appetite['Moderate'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule9 = ctrl.Rule(Fever['Moderate'] & Headache['Mild'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Severe'] & Joint_Pain['Moderate'] & Body_Weakness['Moderate'] & Dizziness['Severe'] & Loss_of_Appetite['Moderate'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule10 = ctrl.Rule(Fever['Mild'] & Headache['Mild'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Moderate'] & Joint_Pain['Mild'] & Body_Weakness['Mild'] & Dizziness['Mild'] & Loss_of_Appetite['Mild'] & MP['Mild'], Diagnosis_Result['Mild'])
rule11 = ctrl.Rule(Fever['Severe'] & Headache['Severe'] & Nausea['Severe'] & Vomiting['Severe'] & Jaundice['Severe'] & Enlarge_Liver['Severe'] & Joint_Pain['Severe'] & Body_Weakness['Very Severe'] & Dizziness['Severe'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Very Severe'])
rule12 = ctrl.Rule(Fever['Moderate'] & Headache['Severe'] & Nausea['Moderate'] & Vomiting['Severe'] & Jaundice['Moderate'] & Enlarge_Liver['Severe'] & Joint_Pain['Moderate'] & Body_Weakness['Severe'] & Dizziness['Moderate'] & Loss_of_Appetite['Mild'] & MP['Moderate'], Diagnosis_Result['Severe'])
rule13 = ctrl.Rule(Fever['Mild'] & Headache['Moderate'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Mild'] & Body_Weakness['Moderate'] & Dizziness['Mild'] & Loss_of_Appetite['Moderate'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule14 = ctrl.Rule(Fever['Severe'] & Headache['Severe'] & Nausea['Moderate'] & Vomiting['Severe'] & Jaundice['Severe'] & Enlarge_Liver['Severe'] & Joint_Pain['Severe'] & Body_Weakness['Severe'] & Dizziness['Moderate'] & Loss_of_Appetite['Moderate'] & MP['Severe'], Diagnosis_Result['Severe'])
rule15 = ctrl.Rule(Fever['Mild'] & Headache['Mild'] & Nausea['Mild'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Mild'] & Body_Weakness['Severe'] & Dizziness['Mild'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Severe'])
rule16 = ctrl.Rule(Fever['Very Severe'] & Headache['Moderate'] & Nausea['Mild'] & Vomiting['Moderate'] & Jaundice['Severe'] & Enlarge_Liver['Moderate'] & Joint_Pain['Mild'] & Body_Weakness['Very Severe'] & Dizziness['Severe'] & Loss_of_Appetite['Mild'] & MP['Moderate'], Diagnosis_Result['Very Severe'])
rule17 = ctrl.Rule(Fever['Mild'] & Headache['Very Severe'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Moderate'] & Joint_Pain['Mild'] & Body_Weakness['Moderate'] & Dizziness['Very Severe'] & Loss_of_Appetite['Mild'] & MP['Moderate'], Diagnosis_Result['Very Severe'])
rule18 = ctrl.Rule(Fever['Moderate'] & Headache['Very Severe'] & Nausea['Very Severe'] & Vomiting['Mild'] & Jaundice['Severe'] & Enlarge_Liver['Severe'] & Joint_Pain['Moderate'] & Body_Weakness['Severe'] & Dizziness['Very Severe'] & Loss_of_Appetite['Very Severe'] & MP['Severe'], Diagnosis_Result['Very Severe'])
rule19 = ctrl.Rule(Fever['Moderate'] & Headache['Moderate'] & Nausea['Moderate'] & Vomiting['Moderate'] & Jaundice['Mild'] & Enlarge_Liver['Mild'] & Joint_Pain['Moderate'] & Body_Weakness['Moderate'] & Dizziness['Moderate'] & Loss_of_Appetite['Moderate'] & MP['Moderate'], Diagnosis_Result['Moderate'])
rule20 = ctrl.Rule(Fever['Very Severe'] & Headache['Severe'] & Nausea['Severe'] & Vomiting['Severe'] & Jaundice['Severe'] & Enlarge_Liver['Severe'] & Joint_Pain['Severe'] & Body_Weakness['Severe'] & Dizziness['Severe'] & Loss_of_Appetite['Severe'] & MP['Moderate'], Diagnosis_Result['Very Severe'])
system_ctrl= ctrl.ControlSystem(rules=[rule1, rule1, rule2, rule3, rule4, rule5,rule6, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule18, rule19, rule20])
system=ctrl.ControlSystemSimulation(system_ctrl)
system.input['Fever']=0.9
system.input['Headache']=0.8
system.input['Nausea']=0.6
system.input['Vomiting']=0.8
system.input['Jaundice']=0.6
system.input['Enlarge_Liver']=0.7
system.input['Joint_Pain']=0.5
system.input['Body_Weakness']=0.6
system.input['Dizziness']=0.5
system.input['Loss_of_Appetite']=0.5
system.input['MP']=0.5
system.compute()
print(system.output['Diagnosis_Result'])
Diagnosis_Result.view(sim=system)
# Out:
# 0.7242424242424242
